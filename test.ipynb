# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import sys, os, math, re
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns # グラフスタイル

#np.set_printoptions?
#np.set_printoptions( precision=3 ) # 有効桁3で丸める、default=8
#np.set_printoptions( precision=3, suppress=True, linewidth=100 ) # 有効桁3で丸める、指数表示の禁止、default=False
np.set_printoptions( suppress=True, linewidth=100 ) # 指数表示の禁止、default=False
#np.set_printoptions( formatter={'float': '{: 0.3f}'.format} ) # 桁を揃える

pd.set_option( 'display.max_columns', 100 )

# %%
FPATH = "./data"

# %%
df = pd.read_csv( os.path.join(FPATH, "Cars93.csv") )

df.head()
# Out:
#    Unnamed: 0 Manufacturer    Model     Type  Min.Price  Price  Max.Price  \
# 0           1        Acura  Integra    Small       12.9   15.9       18.8
# 1           2        Acura   Legend  Midsize       29.2   33.9       38.7
# 2           3         Audi       90  Compact       25.9   29.1       32.3
# 3           4         Audi      100  Midsize       30.8   37.7       44.6
# 4           5          BMW     535i  Midsize       23.7   30.0       36.2
#
#    MPG.city  MPG.highway             AirBags DriveTrain Cylinders  EngineSize  \
# 0        25           31                None      Front         4         1.8
# 1        18           25  Driver & Passenger      Front         6         3.2
# 2        20           26         Driver only      Front         6         2.8
# 3        19           26  Driver & Passenger      Front         6         2.8
# 4        22           30         Driver only       Rear         4         3.5
#
#    Horsepower   RPM  Rev.per.mile Man.trans.avail  Fuel.tank.capacity  \
# 0         140  6300          2890             Yes                13.2
# 1         200  5500          2335             Yes                18.0
# 2         172  5500          2280             Yes                16.9
# 3         172  5500          2535             Yes                21.1
# 4         208  5700          2545             Yes                21.1
#
#    Passengers  Length  Wheelbase  Width  Turn.circle  Rear.seat.room  \
# 0           5     177        102     68           37            26.5
# 1           5     195        115     71           38            30.0
# 2           5     180        102     67           37            28.0
# 3           6     193        106     70           37            31.0
# 4           4     186        109     69           39            27.0
#
#    Luggage.room  Weight   Origin           Make
# 0          11.0    2705  non-USA  Acura Integra
# 1          15.0    3560  non-USA   Acura Legend
# 2          14.0    3375  non-USA        Audi 90
# 3          17.0    3405  non-USA       Audi 100
# 4          13.0    3640  non-USA       BMW 535i

# %%
df.dtypes
# Out:
# Unnamed: 0              int64
# Manufacturer           object
# Model                  object
# Type                   object
# Min.Price             float64
# Price                 float64
# Max.Price             float64
# MPG.city                int64
# MPG.highway             int64
# AirBags                object
# DriveTrain             object
# Cylinders              object
# EngineSize            float64
# Horsepower              int64
# RPM                     int64
# Rev.per.mile            int64
# Man.trans.avail        object
# Fuel.tank.capacity    float64
# Passengers              int64
# Length                  int64
# Wheelbase               int64
# Width                   int64
# Turn.circle             int64
# Rear.seat.room        float64
# Luggage.room          float64
# Weight                  int64
# Origin                 object
# Make                   object
# dtype: object

# %%
sel_col = [ 'MPG.city', 'MPG.highway', 'EngineSize', 'Horsepower', 'RPM', 'Rev.per.mile',
            'Fuel.tank.capacity', 'Passengers', 'Length', 'Wheelbase', 'Width', 'Turn.circle', 'Weight' ]

# %%
df_nu = df.loc[:, sel_col + ['Price']]
print( df_nu.shape )
# Out:
# (93, 14)

# %%
df_nu.describe()
# Out:
#         MPG.city  MPG.highway  EngineSize  Horsepower          RPM  \
# count  93.000000    93.000000   93.000000   93.000000    93.000000
# mean   22.365591    29.086022    2.667742  143.827957  5280.645161
# std     5.619812     5.331726    1.037363   52.374410   596.731690
# min    15.000000    20.000000    1.000000   55.000000  3800.000000
# 25%    18.000000    26.000000    1.800000  103.000000  4800.000000
# 50%    21.000000    28.000000    2.400000  140.000000  5200.000000
# 75%    25.000000    31.000000    3.300000  170.000000  5750.000000
# max    46.000000    50.000000    5.700000  300.000000  6500.000000
#
#        Rev.per.mile  Fuel.tank.capacity  Passengers      Length   Wheelbase  \
# count     93.000000           93.000000   93.000000   93.000000   93.000000
# mean    2332.204301           16.664516    5.086022  183.204301  103.946237
# std      496.506525            3.279370    1.038979   14.602382    6.819674
# min     1320.000000            9.200000    2.000000  141.000000   90.000000
# 25%     1985.000000           14.500000    4.000000  174.000000   98.000000
# 50%     2340.000000           16.400000    5.000000  183.000000  103.000000
# 75%     2565.000000           18.800000    6.000000  192.000000  110.000000
# max     3755.000000           27.000000    8.000000  219.000000  119.000000
#
#            Width  Turn.circle       Weight      Price
# count  93.000000    93.000000    93.000000  93.000000
# mean   69.376344    38.956989  3072.903226  19.509677
# std     3.778986     3.223265   589.896510   9.659430
# min    60.000000    32.000000  1695.000000   7.400000
# 25%    67.000000    37.000000  2620.000000  12.200000
# 50%    69.000000    39.000000  3040.000000  17.700000
# 75%    72.000000    41.000000  3525.000000  23.300000
# max    78.000000    45.000000  4105.000000  61.900000
